# %% [markdown]
# ### Visualizing TTC Subway Delays
#
# Data source: [Toronto Open Data - TTC Subway Delay Data](https://open.toronto.ca/dataset/ttc-subway-delay-data/)
#
# This notebook connects to the opendata api and retrieves the last 12 months of TTC delay. For visualization, we will be looking at delays only related to the subway stations.

# %%
#uncomment these on for full outputs.
#from IPython.core.interactiveshell import InteractiveShell

#InteractiveShell.ast_node_interactivity = "all"
#pd.options.display.max_rows = 4000

# %%
import pandas as pd
import requests
import json
 
# Get the dataset metadata by passing package_id to the package_search endpoint
# For example, to retrieve the metadata for this dataset:
 
url = "https://ckan0.cf.opendata.inter.prod-toronto.ca/api/3/action/package_show"
params = { "id": "996cfe8d-fb35-40ce-b569-698d51fc683b"}
package = requests.get(url, params = params).json()
print(package["result"])

# to export json if needed
# packageJson = json.dumps(package)
# Out:
# {'license_title': 'Open Government Licence – Toronto', 'owner_unit': None, 'relationships_as_object': [], 'topics': 'Transportation', 'owner_email': 'Andrew.Hutt@ttc.ca', 'excerpt': 'TTC Subway Delay Data', 'private': False, 'owner_division': 'Toronto Transit Commission', 'num_tags': 5, 'id': '996cfe8d-fb35-40ce-b569-698d51fc683b', 'metadata_created': '2019-07-23T18:12:29.554797', 'refresh_rate': 'Monthly', 'title': 'TTC Subway Delay Data', 'license_url': 'https://open.toronto.ca/open-data-license/', 'state': 'active', 'information_url': None, 'license_id': 'open-government-licence-toronto', 'type': 'dataset', 'resources': [{'cache_last_updated': None, 'package_id': '996cfe8d-fb35-40ce-b569-698d51fc683b', 'datastore_active': False, 'id': 'fece136b-224a-412a-b191-8d31eb00491e', 'size': 20206, 'format': 'XLSX', 'state': 'active', 'hash': '', 'description': '', 'is_preview': False, 'last_modified': '2019-08-15T16:25:10.332408', 'url_type': 'upload', 'mimetype': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet', 'cache_url': None, 'extract_job': None, 'name': 'ttc-subway-delay-codes', 'created': '2019-07-23T18:12:29.977939', 'url': 'https://ckan0.cf.opendata.inter.prod-toronto.ca/dataset/996cfe8d-fb35-40ce-b569-698d51fc683b/resource/fece136b-224a-412a-b191-8d31eb00491e/download/ttc-subway-delay-codes.xlsx', 'mimetype_inner': None, 'position': 0, 'revision_id': 'c67fd8f7-cf16-41a7-b7f2-d508acaee8f1', 'resource_type': None}, {'cache_last_updated': None, 'package_id': '996cfe8d-fb35-40ce-b569-698d51fc683b', 'datastore_active': False, 'id': '6664420f-316f-4f94-9ba4-d4b4677aeea9', 'size': 3698719, 'format': 'XLSX', 'state': 'active', 'hash': '', 'description': '', 'is_preview': False, 'last_modified': '2019-08-15T16:25:15.670145', 'url_type': 'upload', 'mimetype': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet', 'cache_url': None, 'extract_job': None, 'name': 'ttc-subway-delay-jan-2014-april-2017', 'created': '2019-07-23T18:12:32.134571', 'url': 'https://ckan0.cf.opendata.inter.prod-toronto.ca/dataset/996cfe8d-fb35-40ce-b569-698d51fc683b/resource/6664420f-316f-4f94-9ba4-d4b4677aeea9/download/ttc-subway-delay-jan-2014-april-2017.xlsx', 'mimetype_inner': None, 'position': 1, 'revision_id': 'c67fd8f7-cf16-41a7-b7f2-d508acaee8f1', 'resource_type': None}, {'cache_last_updated': None, 'package_id': '996cfe8d-fb35-40ce-b569-698d51fc683b', 'datastore_active': False, 'id': 'd1159888-0035-45a0-b238-86b546555ac0', 'size': 107731, 'format': 'XLSX', 'state': 'active', 'hash': '', 'description': '', 'is_preview': False, 'last_modified': '2019-08-15T16:25:17.302699', 'url_type': 'upload', 'mimetype': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet', 'cache_url': None, 'extract_job': None, 'name': 'ttc-subway-delay-may-2017', 'created': '2019-07-23T18:12:33.128817', 'url': 'https://ckan0.cf.opendata.inter.prod-toronto.ca/dataset/996cfe8d-fb35-40ce-b569-698d51fc683b/resource/d1159888-0035-45a0-b238-86b546555ac0/download/ttc-subway-delay-may-2017.xlsx', 'mimetype_inner': None, 'position': 2, 'revision_id': 'c67fd8f7-cf16-41a7-b7f2-d508acaee8f1', 'resource_type': None}, {'cache_last_updated': None, 'package_id': '996cfe8d-fb35-40ce-b569-698d51fc683b', 'datastore_active': False, 'id': '240d8e8c-d300-4f91-b94f-cbb3d136d25e', 'size': 95943, 'format': 'XLSX', 'state': 'active', 'hash': '', 'description': '', 'is_preview': False, 'last_modified': '2019-08-15T16:25:19.042255', 'url_type': 'upload', 'mimetype': 'application/vnd.openxmlformats-officedocument.spreadsheetml.sheet', 'cache_url': None, 'extract_job': None, 'name': 'ttc-subway-delay-june-2017', 'created': '2019-07-23T18:12:33.910413', 'url': 'https://ckan0.cf.opendata.inter.prod-toronto.ca/dataset/996cfe8d-fb35-40ce-b569-698d51fc683b/resource/240d8e8c-d300-4f91-b94f-cbb3d136d25e/download/ttc-subway-delay-june-2017.xlsx', 'mimetype_inner': None, 'position': 3, 'revision_id': 'c67fd8f7-cf16-41a7-b7f2-d508acaee8f1', 'resource_type': None}, {'cache ...

# %%
if (len(package["result"]["resources"]) > 12):
    lastTwelve = package["result"]["resources"][-12:]

# %%
df = pd.read_excel(lastTwelve[0]["url"])
for x in lastTwelve[1:]:
    df = df.append(pd.read_excel(x["url"]))

# %%
df
# Out:
#            Date   Time       Day                 Station   Code  Min Delay  \
# 0    2020-10-01  00:00  Thursday         MCCOWAN STATION   ERTC          6
# 1    2020-10-01  00:08  Thursday       LANSDOWNE STATION   EUNT          5
# 2    2020-10-01  07:44  Thursday             BAY STATION   SUDP          0
# 3    2020-10-01  09:01  Thursday      KENNEDY BD STATION   MUTO          3
# 4    2020-10-01  09:08  Thursday          LESLIE STATION   TUSC          0
# ...         ...    ...       ...                     ...    ...        ...
# 1428 2021-09-30  23:29  Thursday      VAUGHAN MC STATION  TUNOA          3
# 1429 2021-09-30  00:40  Thursday          DUNDAS STATION   MUIS          0
# 1430 2021-09-30  01:46  Thursday            PAPE STATION   SUUT         11
# 1431 2021-09-30  16:04  Thursday         BAYVIEW STATION   EUSC          0
# 1432 2021-09-30  18:40  Thursday  SHEPPARD-YONGE STATION   MUSC          0
#
#       Min Gap Bound Line  Vehicle
# 0          12     S  SRT     3026
# 1          11     W   BD     5021
# 2           0     E   BD     5167
# 3           6     W   BD     5167
# 4           0     W  SHP     6181
# ...       ...   ...  ...      ...
# 1428        6     S   YU     5476
# 1429        0   NaN   YU        0
# 1430       18     W   BD     5259
# 1431        0     E  SHP     6176
# 1432        0     E  SHP     6171
#
# [15017 rows x 10 columns]

# %%
df.isnull().value_counts()
# Out:
# Date   Time   Day    Station  Code   Min Delay  Min Gap  Bound  Line   Vehicle
# False  False  False  False    False  False      False    False  False  False      11016
#                                                          True   False  False       3952
#                                                                 True   False         42
#                                                          False  True   False          7
# dtype: int64

# %%
df.fillna("N/A", inplace=True)

# %%
df[df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Date, Time, Day, Station, Code, Min Delay, Min Gap, Bound, Line, Vehicle]
# Index: []

# %%
df["Station"].value_counts()
# Out:
# VAUGHAN MC STATION        780
# FINCH STATION             731
# KENNEDY BD STATION        504
# BLOOR STATION             491
# WARDEN STATION            485
#                          ...
# KIPLING - ISLIINGTON S      1
# KILPING STATION             1
# GUNN BUILDING               1
# SHEPPARD TAIL TRACK #2      1
# YONGE-UNIVERSITY / BLO      1
# Name: Station, Length: 289, dtype: int64

# %%
df["Station"].value_counts()[df["Station"].value_counts()>50]
# Out:
# VAUGHAN MC STATION        780
# FINCH STATION             731
# KENNEDY BD STATION        504
# BLOOR STATION             491
# WARDEN STATION            485
#                          ...
# ST PATRICK STATION         62
# SCARBOROUGH RAPID TRAN     61
# DOWNSVIEW PARK STATION     59
# QUEEN'S PARK STATION       57
# LAWRENCE EAST STATION      56
# Name: Station, Length: 79, dtype: int64

# %%
df["Day"].value_counts()
# Out:
# Thursday     2347
# Monday       2251
# Wednesday    2238
# Friday       2222
# Tuesday      2196
# Saturday     1905
# Sunday       1858
# Name: Day, dtype: int64

# %%
df["Code"].value_counts()
# Out:
# SUDP     1853
# MUIS     1513
# MUPAA     941
# MUO       914
# MUSC      637
#          ...
# TRTC        1
# ERTB        1
# MUODC       1
# SREAS       1
# MRIE        1
# Name: Code, Length: 171, dtype: int64

# %% [markdown]
# ### Loading in TTC Subway Delay Codes
#
# In order to make sense of what the code values in the delay tables are, we read in the TTC subway delay codes. This can also be in the URL mentioned above.

# %%
# read code csv
df_codes = pd.read_excel("data/ttc-subway-delay-codes.xlsx")

# %%
# the resulting dataframe has multiple columns
df_codes
# Out:
#      Unnamed: 0  Unnamed: 1      Unnamed: 2  \
# 0           NaN         NaN  SUB RMENU CODE
# 1           NaN         1.0            EUAC
# 2           NaN         2.0            EUAL
# 3           NaN         3.0           EUATC
# 4           NaN         4.0            EUBK
# ..          ...         ...             ...
# 125         NaN       125.0             TUS
# 126         NaN       126.0            TUSC
# 127         NaN       127.0           TUSET
# 128         NaN       128.0            TUST
# 129         NaN       129.0           TUSUP
#
#                               Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0                       CODE DESCRIPTION         NaN         NaN
# 1                       Air Conditioning         NaN         1.0
# 2                    Alternating Current         NaN         2.0
# 3                     ATC RC&S Equipment         NaN         3.0
# 4                                 Brakes         NaN         4.0
# ..                                   ...         ...         ...
# 125     Crew Unable to Maintain Schedule         NaN         NaN
# 126                Operator Overspeeding         NaN         NaN
# 127  Train Controls Improperly Shut Down         NaN         NaN
# 128                         Storm Trains         NaN         NaN
# 129                    Supervisory Error         NaN         NaN
#
#          Unnamed: 6                                  Unnamed: 7
# 0    SRT RMENU CODE                            CODE DESCRIPTION
# 1              ERAC                            Air Conditioning
# 2              ERBO                                        Body
# 3              ERCD  Consequential Delay (2nd Delay Same Fault)
# 4              ERCO                                    Couplers
# ..              ...                                         ...
# 125             NaN                                         NaN
# 126             NaN                                         NaN
# 127             NaN                                         NaN
# 128             NaN                                         NaN
# 129             NaN                                         NaN
#
# [130 rows x 8 columns]

# %%
df_codes.drop(columns=['Unnamed: 0','Unnamed: 1','Unnamed: 4','Unnamed: 5'], inplace=True)

# %%
df_codes
# Out:
#          Unnamed: 2                           Unnamed: 3      Unnamed: 6  \
# 0    SUB RMENU CODE                     CODE DESCRIPTION  SRT RMENU CODE
# 1              EUAC                     Air Conditioning            ERAC
# 2              EUAL                  Alternating Current            ERBO
# 3             EUATC                   ATC RC&S Equipment            ERCD
# 4              EUBK                               Brakes            ERCO
# ..              ...                                  ...             ...
# 125             TUS     Crew Unable to Maintain Schedule             NaN
# 126            TUSC                Operator Overspeeding             NaN
# 127           TUSET  Train Controls Improperly Shut Down             NaN
# 128            TUST                         Storm Trains             NaN
# 129           TUSUP                    Supervisory Error             NaN
#
#                                      Unnamed: 7
# 0                              CODE DESCRIPTION
# 1                              Air Conditioning
# 2                                          Body
# 3    Consequential Delay (2nd Delay Same Fault)
# 4                                      Couplers
# ..                                          ...
# 125                                         NaN
# 126                                         NaN
# 127                                         NaN
# 128                                         NaN
# 129                                         NaN
#
# [130 rows x 4 columns]

# %%
df_left = df_codes[['Unnamed: 2','Unnamed: 3']].rename(columns={"Unnamed: 2": "Code", "Unnamed: 3": "Code Description"})
df_left
# Out:
#                Code                     Code Description
# 0    SUB RMENU CODE                     CODE DESCRIPTION
# 1              EUAC                     Air Conditioning
# 2              EUAL                  Alternating Current
# 3             EUATC                   ATC RC&S Equipment
# 4              EUBK                               Brakes
# ..              ...                                  ...
# 125             TUS     Crew Unable to Maintain Schedule
# 126            TUSC                Operator Overspeeding
# 127           TUSET  Train Controls Improperly Shut Down
# 128            TUST                         Storm Trains
# 129           TUSUP                    Supervisory Error
#
# [130 rows x 2 columns]

# %%
df_right = df_codes[['Unnamed: 6','Unnamed: 7']].rename(columns={"Unnamed: 6": "Code", "Unnamed: 7": "Code Description"})
df_right = df_right.dropna()
df_right
# Out:
#               Code                            Code Description
# 0   SRT RMENU CODE                            CODE DESCRIPTION
# 1             ERAC                            Air Conditioning
# 2             ERBO                                        Body
# 3             ERCD  Consequential Delay (2nd Delay Same Fault)
# 4             ERCO                                    Couplers
# ..             ...                                         ...
# 67           TRNOA          No Operator Immediately Available
# 68             TRO           Transportation Department - Other
# 69           TRSET         Train Controls Improperly Shut Down
# 70            TRST                                Storm Trains
# 71            TRTC            Transit Control Related Problems
#
# [72 rows x 2 columns]

# %%
df_mergedCodes = df_left.append(df_right, ignore_index=True)
df_mergedCodes
# Out:
#                Code                     Code Description
# 0    SUB RMENU CODE                     CODE DESCRIPTION
# 1              EUAC                     Air Conditioning
# 2              EUAL                  Alternating Current
# 3             EUATC                   ATC RC&S Equipment
# 4              EUBK                               Brakes
# ..              ...                                  ...
# 197           TRNOA   No Operator Immediately Available
# 198             TRO    Transportation Department - Other
# 199           TRSET  Train Controls Improperly Shut Down
# 200            TRST                         Storm Trains
# 201            TRTC     Transit Control Related Problems
#
# [202 rows x 2 columns]

# %%
len(df_mergedCodes)
# Out:
# 202

# %%
# Add code type column
start_sub = df_mergedCodes.index[df_mergedCodes["Code"] == 'SUB RMENU CODE']
end_sub =  df_mergedCodes.index[df_mergedCodes["Code"] == 'SRT RMENU CODE']

df_mergedCodes["Type"] = ['SUB RMENU CODE' if x<130 else "SRT RMENU CODE" for x in range(len(df_mergedCodes))]

# %%
df_mergedCodes["Code"].value_counts()
# Out:
# PUTSC    1
# EUNEA    1
# PUTO     1
# EUTM     1
# PUSCR    1
#         ..
# EUHV     1
# TRO      1
# EUTRD    1
# PUTNT    1
# ERME     1
# Name: Code, Length: 202, dtype: int64

# %%
df_mergedCodes.drop(df_mergedCodes.loc[df_mergedCodes["Code"] == "SUB RMENU CODE"].index, inplace=True)
df_mergedCodes.drop(df_mergedCodes.loc[df_mergedCodes["Code"] == "SRT RMENU CODE"].index, inplace=True)

# %%
df_mergedCodes
# Out:
#       Code                     Code Description            Type
# 1     EUAC                     Air Conditioning  SUB RMENU CODE
# 2     EUAL                  Alternating Current  SUB RMENU CODE
# 3    EUATC                   ATC RC&S Equipment  SUB RMENU CODE
# 4     EUBK                               Brakes  SUB RMENU CODE
# 5     EUBO                                 Body  SUB RMENU CODE
# ..     ...                                  ...             ...
# 197  TRNOA   No Operator Immediately Available   SRT RMENU CODE
# 198    TRO    Transportation Department - Other  SRT RMENU CODE
# 199  TRSET  Train Controls Improperly Shut Down  SRT RMENU CODE
# 200   TRST                         Storm Trains  SRT RMENU CODE
# 201   TRTC     Transit Control Related Problems  SRT RMENU CODE
#
# [200 rows x 3 columns]

# %%
# Merge error code with last 12 months
df_full = df.merge(df_mergedCodes, on="Code", how="left")

# %%
df_full
# Out:
#             Date   Time       Day                 Station   Code  Min Delay  \
# 0     2020-10-01  00:00  Thursday         MCCOWAN STATION   ERTC          6
# 1     2020-10-01  00:08  Thursday       LANSDOWNE STATION   EUNT          5
# 2     2020-10-01  07:44  Thursday             BAY STATION   SUDP          0
# 3     2020-10-01  09:01  Thursday      KENNEDY BD STATION   MUTO          3
# 4     2020-10-01  09:08  Thursday          LESLIE STATION   TUSC          0
# ...          ...    ...       ...                     ...    ...        ...
# 15012 2021-09-30  23:29  Thursday      VAUGHAN MC STATION  TUNOA          3
# 15013 2021-09-30  00:40  Thursday          DUNDAS STATION   MUIS          0
# 15014 2021-09-30  01:46  Thursday            PAPE STATION   SUUT         11
# 15015 2021-09-30  16:04  Thursday         BAYVIEW STATION   EUSC          0
# 15016 2021-09-30  18:40  Thursday  SHEPPARD-YONGE STATION   MUSC          0
#
#        Min Gap Bound Line  Vehicle  \
# 0           12     S  SRT     3026
# 1           11     W   BD     5021
# 2            0     E   BD     5167
# 3            6     W   BD     5167
# 4            0     W  SHP     6181
# ...        ...   ...  ...      ...
# 15012        6     S   YU     5476
# 15013        0   N/A   YU        0
# 15014       18     W   BD     5259
# 15015        0     E  SHP     6176
# 15016        0     E  SHP     6171
#
#                                         Code Description            Type
# 0                                   Train Control - VOBC  SRT RMENU CODE
# 1                           Equipment - No Trouble Found  SUB RMENU CODE
# 2                                      Disorderly Patron  SUB RMENU CODE
# 3      Misc. Transportation Other - Employee Non-Char...  SUB RMENU CODE
# 4                                  Operator Overspeeding  SUB RMENU CODE
# ...                                                  ...             ...
# 15012                 No Operator Immediately Available   SUB RMENU CODE
# 15013  Injured or ill Customer (In Station) - Transpo...  SUB RMENU CODE
# 15014                        Unauthorized at Track Level  SUB RMENU CODE
# 15015                          Speed Control Equipment    SUB RMENU CODE
# 15016                        Miscellaneous Speed Control  SUB RMENU CODE
#
# [15017 rows x 12 columns]

# %%
# export to excel
df_full.to_csv("output/12_months_ttc.csv")

# %% [markdown]
# ### Explore Station Data
# Let's explore the station data. There are also some cells where no error code coud be found.

# %%
df_station = df_full.copy()

# %%
df_station["Station"].value_counts()[df["Station"].value_counts()<60]
# Out:
# DOWNSVIEW PARK STATION    59
# QUEEN'S PARK STATION      57
# LAWRENCE EAST STATION     56
# GLENCAIRN STATION         49
# YORK UNIVERSITY STATIO    45
#                           ..
# KIPLING - ISLIINGTON S     1
# KILPING STATION            1
# GUNN BUILDING              1
# SHEPPARD TAIL TRACK #2     1
# YONGE-UNIVERSITY / BLO     1
# Name: Station, Length: 213, dtype: int64

# %%
df_station["Station"].groupby(df_station["Station"]).head()
# Out:
# 0               MCCOWAN STATION
# 1             LANSDOWNE STATION
# 2                   BAY STATION
# 3            KENNEDY BD STATION
# 4                LESLIE STATION
#                   ...
# 14857    YONGE/UNIVERSITY/SPADI
# 14860    YONGE/UNIVERSITY/SPADI
# 14914    YONGE/UNIVERSITY/SPADI
# 14918    YONGE/UNIVERSITY/SPADI
# 14957    KING STATION TO EGLINT
# Name: Station, Length: 798, dtype: object

# %%
station_list = df_station["Station"].apply(lambda x: x.split()[-1])
station_list.groupby(station_list).count().sort_values()
# Out:
# Station
# #2                            1
# SHEP                          1
# ROSEDALE                      1
# R                             1
# PIONEER                       1
# OSGO                          1
# MI                            1
# MCCOWA                        1
# YONGE/UNIVERSITY-SPADI        1
# LIN                           1
# L                             1
# KIPLING                       1
# KEN                           1
# ISLINGTON                     1
# HOUSE                         1
# GEO                           1
# GARAGE                        1
# FI                            1
# SHEPAPRD/YO                   1
# ENTRANCE                      1
# SHEPPARD-YONGE                1
# ST.A                          1
# WOO                           1
# WARDE                         1
# VILLAGE                       1
# UNIVERSITY/BLOOR              1
# UNION                         1
# TRA                           1
# TR                            1
# TAIL                          1
# TAI                           1
# T&S                           1
# T                             1
# SUBSTATION                    1
# SUBSTATI                      1
# STEELES                       1
# STATO                         1
# STATIONS                      1
# STAITON                       1
# SHOPS                         1
# EGLINT                        1
# MARKDALE                      1
# BEDFORD                       1
# (LEAVIN                       1
# 3                             1
# 4                             1
# (ENTE                         1
# AND                           1
# (BD)                          1
# (APPRO                        1
# BD                            1
# (APPR                         1
# BLOO                          1
# BLOOR                         1
# BROADVIEW                     1
# BUIL                          1
# BUILDUP                       1
# (APP                          1
# BROADVIE                      1
# (EXIT                         1
# CONTROL                       1
# COLLEGE                       1
# DANFORTH                      1
# COX                           1
# CLA                           1
# DAVISVILLE                    1
# SYSTEMWIDE                    2
# TRAC                          2
# SPADIN                        2
# A                             2
# AN                            2
# EXIT                          2
# VIADUCT                       2
# ISL                           2
# CONTRO                        2
# ST                            2
# SPADI                         2
# JAN                           2
# MCCOWAN                       2
# KIN                           2
# WES                           2
# RT                            2
# S                             2
# WILSON                        2
# BUILD-UP                      2
# CL                            2
# YONGE-UNIVERSITY/BLOOR        2
# PORTAL                        3
# 1                             3
# SHEPPARD                      3
# SHOP                          3
# HOSTLER                       3
# TRACK                         3
# STA                           3
# BLO                           3
# CENTRE                        4
# ANDREW                        4
# W                             4
# (LEAV                         4
# EGLIN                         4
# KENNEDY                       4
# LAWRE                         4
# LAWRENCE                      4
# VAU                           5
# WYE                           5
# DIVISION                      5
# SRT                           5
# YONGE/UNIVERSITY/SPADI        5
# BUILDING                      6
# KING                          7
# WILSO                         7
# UP                            8
# STATI                         8
# SUBW                          9
# SUBWAY                       12
# STAT                         17
# CARHOUSE                     18
# LINE                         40
# TRAN                         62
# YARD                         72
# SUBWA                        85
# COMMIS                      114
# STATIO                      219
# B                           300
# STATION                   13844
# Name: Station, dtype: int64

# %% [markdown]
# From above, we see that there are a few typos, and words other than station. Let's fix all stations words, and drop all other entries as we will only be concerned with the stations themselves.
# STATO
# STAITON
# STATI
# STATIO

# %%
# Create a dictionary to fix the entries, mark non-stations as NA
station_dict = {"STATO": "STATION", "STATIONS": "STATION", "STAITON": "STATION", "STATI": "STATION", "STATIO": "STATION", "STATION":"STATION"}
station_list2 = station_list.apply(lambda x: "NA" if station_dict.get(x) is None else station_dict.get(x))

# %%
station_list2
# Out:
# 0        STATION
# 1        STATION
# 2        STATION
# 3        STATION
# 4        STATION
#           ...
# 15012    STATION
# 15013    STATION
# 15014    STATION
# 15015    STATION
# 15016    STATION
# Name: Station, Length: 15017, dtype: object

# %%
station_list2.groupby(station_list2).count().sort_values()
# Out:
# Station
# NA           943
# STATION    14074
# Name: Station, dtype: int64

# %%
# Out:
# 0        STATION
# 1        STATION
# 2        STATION
# 3        STATION
# 4        STATION
#           ...
# 15012    STATION
# 15013    STATION
# 15014    STATION
# 15015    STATION
# 15016    STATION
# Name: Station, Length: 15017, dtype: object
